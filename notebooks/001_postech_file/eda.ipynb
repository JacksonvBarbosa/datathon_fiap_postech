# %% [markdown]
# # Análise dos Dados tradados

# %%
# Libs
import pandas as pd
import matplotlib as plt
import seaborn as sns
import scipy as scy

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv('../../data/processed/base_de_dados_completo_eda.csv')
df.head(3)
# Out:
#   data_referencia      ra fase turma       nome  ano_nasc  idade_22  gênero  \
# 0      2022-01-01    RA-1    7     A    Aluno-1    2003.0      19.0  Menina
# 1      2022-01-01   RA-61    5     B   Aluno-61    2007.0      15.0  Menino
# 2      2022-01-01  RA-610    1     L  Aluno-610    2013.0       9.0  Menina
#
#    ano_ingresso instituição_de_ensino  pedra_20  pedra_21  pedra_22  inde_22  \
# 0          2016        Escola Pública  Ametista  Ametista   Quartzo    5.783
# 1          2021        Escola Pública       NaN     Ágata  Ametista    7.533
# 2          2022        Escola Pública       NaN       NaN   Topázio    8.180
#
#       cg    cf    ct  nº_av   avaliador1                rec_av1    avaliador2  \
# 0  753.0  18.0  10.0    4.0  Avaliador-5  Mantido na Fase atual  Avaliador-27
# 1  298.0  20.0   8.0    3.0  Avaliador-5  Mantido na Fase atual  Avaliador-27
# 2   91.0  21.0   3.0    3.0  Avaliador-4  Mantido na Fase atual   Avaliador-2
#
#                      rec_av2    avaliador3                    rec_av3  \
# 0  Promovido de Fase + Bolsa  Avaliador-28          Promovido de Fase
# 1      Mantido na Fase atual  Avaliador-24  Promovido de Fase + Bolsa
# 2          Promovido de Fase           NaN      Mantido na Fase atual
#
#      avaliador4                rec_av4  iaa  ieg  ips    rec_psicologia  ida  \
# 0  Avaliador-31  Mantido na Fase atual  8.3  4.1  5.6  Requer avaliação  4.0
# 1  Avaliador-31                    NaN  9.2  7.4  7.5      Não atendido  5.8
# 2           NaN                    NaN  9.0  9.6  7.5    Sem limitações  6.5
#
#    matem  portug  inglês indicado atingiu_pv    ipv   ian  \
# 0    2.7     3.5     6.0      Sim        Não  7.278   5.0
# 1    1.7     6.3     9.3      Sim        Não  7.875  10.0
# 2    6.0     7.0     NaN      Não        Sim  8.500  10.0
#
#                 fase_ideal  defasagem  \
# 0  Fase 8 (Universitários)         -1
# 1           Fase 5 (1º EM)          0
# 2          Fase 1 (4º ano)          0
#
#                                           destaque_ieg  \
# 0  Melhorar: Melhorar a sua entrega de lições de casa.
# 1  Melhorar: Melhorar a sua entrega de lições de casa.
# 2      Destaque: A sua boa entrega das lições de casa.
#
#                                          destaque_ida  \
# 0  Melhorar: Empenhar-se mais nas aulas e avaliações.
# 1  Melhorar: Empenhar-se mais nas aulas e avaliações.
# 2  Melhorar: Empenhar-se mais nas aulas e avaliações.
#
#                                                     destaque_ipv  \
# 0      Melhorar: Integrar-se mais aos Princípios Passos Mágicos.
# 1  Destaque: A sua boa integração aos Princípios Passos Mágicos.
# 2  Destaque: A sua boa integração aos Princípios Passos Mágicos.
#
#    ano_referencia  inde_2023 pedra_2023 nome_anonimizado data_de_nasc idade  \
# 0            2022        NaN        NaN              NaN          NaN   NaN
# 1            2022        NaN        NaN              NaN          NaN   NaN
# 2            2022        NaN        NaN              NaN          NaN   NaN
#
#   pedra_23  inde_23  ipp  mat  por  ing fase_ideal.1  destaque_ipv_1  \
# 0      NaN      NaN  NaN  NaN  NaN  NaN          NaN             NaN
# 1      NaN      NaN  NaN  NaN  NaN  NaN          NaN             NaN
# 2      NaN      NaN  NaN  NaN  NaN  NaN          NaN             NaN
#
#   inde_2024 pedra_2024 avaliador5 avaliador6 escola ativo/inativo  \
# 0       NaN        NaN        NaN        NaN    NaN           NaN
# 1       NaN        NaN        NaN        NaN    NaN           NaN
# 2       NaN        NaN        NaN        NaN    NaN           NaN
#
#   ativo/inativo_1
# 0             NaN
# 1             NaN
# 2             NaN

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3030 entries, 0 to 3029
# Data columns (total 64 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   data_referencia        3030 non-null   str
#  1   ra                     3030 non-null   str
#  2   fase                   3030 non-null   str
#  3   turma                  3030 non-null   str
#  4   nome                   860 non-null    str
#  5   ano_nasc               860 non-null    float64
#  6   idade_22               860 non-null    float64
#  7   gênero                 3030 non-null   str
#  8   ano_ingresso           3030 non-null   int64
#  9   instituição_de_ensino  3029 non-null   str
#  10  pedra_20               754 non-null    str
#  11  pedra_21               1061 non-null   str
#  12  pedra_22               1932 non-null   str
#  13  inde_22                1932 non-null   float64
#  14  cg                     860 non-null    float64
#  15  cf                     860 non-null    float64
#  16  ct                     860 non-null    float64
#  17  nº_av                  2954 non-null   float64
#  18  avaliador1             2827 non-null   str
#  19  rec_av1                860 non-null    str
#  20  avaliador2             2827 non-null   str
#  21  rec_av2                860 non-null    str
#  22  avaliador3             2034 non-null   str
#  23  rec_av3                860 non-null    str
#  24  avaliador4             1051 non-null   str
#  25  rec_av4                296 non-null    str
#  26  iaa                    2865 non-null   float64
#  27  ieg                    2954 non-null   float64
#  28  ips                    2859 non-null   float64
#  29  rec_psicologia         860 non-null    str
#  30  ida                    2852 non-null   float64
#  31  matem                  858 non-null    float64
#  32  portug                 858 non-null    float64
#  33  inglês                 283 non-null    float64
#  34  indicado               860 non-null    str
#  35  atingiu_pv             860 non-null    str
#  36  ipv                    2852 non-null   float64
#  37  ian                    3030 non-null   float64
#  38  fase_ideal             860 non-null    str
#  39  defasagem              3030 non-null   int64
#  40  destaque_ieg           860 non-null    str
#  41  destaque_ida           860 non-null    str
#  42  destaque_ipv           860 non-null    str
#  43  ano_referencia         3030 non-null   int64
#  44  inde_2023              931 non-null    float64
#  45  pedra_2023             931 non-null    str
#  46  nome_anonimizado       2170 non-null   str
#  47  data_de_nasc           2170 non-null   str
#  48  idade                  2170 non-null   str
#  49  pedra_23               690 non-null    str
#  50  inde_23                690 non-null    float64
#  51  ipp                    1992 non-null   float64
#  52  mat                    1988 non-null   float64
#  53  por                    1987 non-null   float64
#  54  ing                    808 non-null    float64
#  55  fase_ideal.1           2170 non-null   str
#  56  destaque_ipv_1         0 non-null      float64
#  57  inde_2024              1092 non-null   str
#  58  pedra_2024             1092 non-null   str
#  59  avaliador5             148 non-null    str
#  60  avaliador6             6 non-null      str
#  61  escola                 1155 non-null   str
#  62  ativo/inativo          1156 non-null   str
#  63  ativo/inativo_1        1156 non-null   str
# dtypes: float64(23), int64(3), str(38)
# memory usage: 2.2 MB

# %% [markdown]
# # Perguntas a serem respondidas
#
# 5. Aspectos psicossociais (IPS): Há padrões psicossociais (IPS) que
# antecedem quedas de desempenho acadêmico ou de engajamento?
#
# Resposta: **Embora não haja uma correlação direta imediata, observou-se que uma queda significativa no bem-estar psicossocial (IPS) em um ano (ex: 2023) precede uma queda no desempenho acadêmico (IDA) e no engajamento (IEG) no ano seguinte (2024).
# Sinal de Alerta: A queda de 1,78 pontos no IPS médio entre 2022 e 2023 serviu como um 'aviso', antes mesmo das notas ou da participação caírem**
#
# 6. Aspectos psicopedagógicos (IPP): As avaliações psicopedagógicas
# (IPP) confirmam ou contradizem a defasagem identificada pelo IAN?
#
# Resposta: **Não ha correlação entre as duas metricas e quando vemos a serie temporial das duas correlação de 0,12 é considerada muito baixa, indicando que as avaliações psicopedagógicas (IPP) e o indicador de aprendizado/defasagem (IAN) medem dimensões diferentes e não variam de forma sincronizada. Além disso, os valores temporais confirmam que enquanto o IPP permaneceu estável (7,56 para 7,55), o IAN (defasagem) teve uma melhora de 7,24 para 7,68, mostrando que o desempenho reportado evoluiu independentemente da percepção psicopedagógica média**
#
# 7. Ponto de virada (IPV): Quais comportamentos - acadêmicos,
# emocionais ou de engajamento - mais influenciam o IPV ao longo do tempo?
#
# Resposta:**Metricas consideradas Emocionais e de engajamento podem tendem a ter maior influencia ao IPV (indicador de ponto de virada), dado que enquanto os indicadores IPS e IAA (emocionais) caem ao longo do tempo, o IPV tende tambem a cair no ano seguinte, já o indicador IEG (Engajamento) tende a ter o mesmo comportamento que o IPV, ou seja, se ele subir, o indicador de IPV também sobe, do contrário o mesmo. Já o unico indicador Acadêmico que possui uma certa relação com o IPV é o IDA, dado que se ele sobre o IPV tambem sobe e de tiver queda há tendencia de ter queda tambem.**
#
# 10. Efetividade do programa: Os indicadores mostram melhora
# consistente ao longo do ciclo nas diferentes fases (Quartzo, Ágata, Ametista e
# Topázio), confirmando o impacto real do programa?
#
# Resposta:**O programa demonstra um impacto real e positivo ao promover uma trajetória de crescimento consistente, onde o avanço de 30,5% dos alunos veteranos (105 alunos) para categorias superiores reflete um progresso qualitativo significativo no desenvolvimento educacional de 2023 a 2024. Além disso, a manutenção de 60% da base em níveis de excelência, como Ametista e Topázio, confirma a eficácia do projeto em consolidar o aprendizado e manter os estudantes em patamares elevados de desempenho acadêmico e emocional. Atraves desse estudo temporal podemos ver que a Associação cumpre sua missão de transformar a realidade dos jovens por meio da educação**

# %% [markdown]
# #Carregando DF

# %%
from logging import warning
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np

# %%
# Substitua pela sua URL Raw do
url = 'https://raw.githubusercontent.com/JacksonvBarbosa/datathon_fiap_postech/refs/heads/main/data/processed/base_de_dados_completo_eda.csv'

# Carregar o dataset

df = pd.read_csv(url)
df.head()
# Out:
#   data_referencia      ra fase turma       nome  ano_nasc  idade_22  gênero  \
# 0      2022-01-01    RA-1    7     A    Aluno-1    2003.0      19.0  Menina
# 1      2022-01-01   RA-61    5     B   Aluno-61    2007.0      15.0  Menino
# 2      2022-01-01  RA-610    1     L  Aluno-610    2013.0       9.0  Menina
# 3      2022-01-01  RA-611    1     M  Aluno-611    2010.0      12.0  Menino
# 4      2022-01-01  RA-612    1     M  Aluno-612    2012.0      10.0  Menina
#
#    ano_ingresso instituição_de_ensino  ... ing fase_ideal.1 destaque_ipv_1  \
# 0          2016        Escola Pública  ... NaN          NaN            NaN
# 1          2021        Escola Pública  ... NaN          NaN            NaN
# 2          2022        Escola Pública  ... NaN          NaN            NaN
# 3          2021        Escola Pública  ... NaN          NaN            NaN
# 4          2021        Escola Pública  ... NaN          NaN            NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3030 entries, 0 to 3029
# Data columns (total 64 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   data_referencia        3030 non-null   object
#  1   ra                     3030 non-null   object
#  2   fase                   3030 non-null   object
#  3   turma                  3030 non-null   object
#  4   nome                   860 non-null    object
#  5   ano_nasc               860 non-null    float64
#  6   idade_22               860 non-null    float64
#  7   gênero                 3030 non-null   object
#  8   ano_ingresso           3030 non-null   int64
#  9   instituição_de_ensino  3029 non-null   object
#  10  pedra_20               754 non-null    object
#  11  pedra_21               1061 non-null   object
#  12  pedra_22               1932 non-null   object
#  13  inde_22                1932 non-null   float64
# ...

# %%
df ['ian'].head()
# Out:
# 0     5.0
# 1    10.0
# 2    10.0
# 3     5.0
# 4     5.0
# Name: ian, dtype: float64

# %%
df ['ida'].describe()
# Out:
# count    2852.000000
# mean        6.375964
# std         1.956637
# min         0.000000
# 25%         5.100000
# 50%         6.666667
# 75%         7.833333
# max        10.000000
# Name: ida, dtype: float64

# %%
df1 = df['data_referencia'].count()
df1
# Out:
# np.int64(3030)

# %%
#níveis de IAN e defasagem

df1 = df.groupby(['defasagem'])['ian'].mean().reset_index().round(2).sort_values(by='defasagem', ascending=False)
df1
# Out:
#    defasagem   ian
# 8          3  10.0
# 7          2  10.0
# 6          1  10.0
# 5          0  10.0
# 4         -1   5.0
# 3         -2   5.0
# 2         -3   2.5
# 1         -4   2.5
# 0         -5   2.5

# %%
#como IAN evolui ao longo dos anos

df1 = df.groupby(['data_referencia'])['ian'].mean().reset_index().round(2)
df1
# Out:
#   data_referencia   ian
# 0      2022-01-01  6.42
# 1      2023-01-01  7.24
# 2      2024-01-01  7.68

# %%
#como IAN evolui ao longo dos anos e defasagem
df1 = df.groupby(['defasagem','data_referencia'])['ian'].mean().reset_index().round(2).sort_values(by='defasagem', ascending=False)
df1
# Out:
#     defasagem data_referencia   ian
# 21          3      2024-01-01  10.0
# 19          2      2023-01-01  10.0
# 18          2      2022-01-01  10.0
# 20          2      2024-01-01  10.0
# 15          1      2022-01-01  10.0
# 17          1      2024-01-01  10.0
# 16          1      2023-01-01  10.0
# 14          0      2024-01-01  10.0
# 13          0      2023-01-01  10.0
# 12          0      2022-01-01  10.0
# 10         -1      2023-01-01   5.0
# 9          -1      2022-01-01   5.0
# 11         -1      2024-01-01   5.0
# 7          -2      2023-01-01   5.0
# 8          -2      2024-01-01   5.0
# 6          -2      2022-01-01   5.0
# 3          -3      2022-01-01   2.5
# 4          -3      2023-01-01   2.5
# 5          -3      2024-01-01   2.5
# 1          -4      2022-01-01   2.5
# 2          -4      2023-01-01   2.5
# 0          -5      2022-01-01   2.5

# %%
df2 = df[['defasagem', "ian", 'instituição_de_ensino']]
sns.pairplot(df2, hue ='instituição_de_ensino')

# %% [markdown]
# # Análises para pergunta 5

# %%
#níveis de IAN e defasagem

df1 = df.groupby(['ips'])['ida'].mean().reset_index().round(2).sort_values(by='ida', ascending=False)
df1
# Out:
#       ips   ida
# 53   9.38  8.46
# 0    2.50  8.10
# 39   7.20  7.86
# 12   4.39  7.81
# 44   8.10  7.62
# 32   6.57  7.58
# 55   9.40  7.51
# 22   5.64  7.50
# 52   8.80  7.19
# 7    3.77  7.13
# 48   8.14  7.13
# 43   7.52  6.96
# 41   7.50  6.95
# 28   6.27  6.90
# 36   6.89  6.88
# 4    3.14  6.86
# 6    3.76  6.82
# 19   5.62  6.82
# 11   4.38  6.75
# 34   6.88  6.71
# 21   5.64  6.57
# 42   7.51  6.53
# 17   5.02  6.51
# 3    3.14  6.50
# 27   6.26  6.49
# 23   5.94  6.40
# 2    2.52  6.34
# 46   8.13  6.34
# 45   8.12  6.33
# 47   8.14  6.30
# 1    2.51  6.28
# 54   9.38  6.26
# 18   5.60  6.20
# 13   4.40  6.13
# 5    3.76  6.11
# 40   7.50  6.10
# 37   6.90  6.08
# 25   6.26  6.05
# 35   6.88  6.00
# 20   5.63  5.95
# 10   4.38  5.93
# 15   5.00  5.91
# 51   8.76  5.82
# 56  10.00  5.80
# 29   6.30  5.78
# 50   8.76  5.77
# 14   5.00  5.66
# 16   5.01  5.56
# 9    4.38  4.75
# 24   6.25  4.75
# 33   6.88  4.17
# 49   8.75  4.17
# 31   6.57  3.96
# 26   6.26  3.74
# ...

# %%
#níveis de IAN e defasagem

media_ips = df.groupby(['ips']).agg(
    desempenho_academico=('ida', 'mean'),
    engajamento=('ieg', 'mean'),
).reset_index().round(2).sort_values(by='ips', ascending=False)

media_ips
# Out:
#       ips  desempenho_academico  engajamento
# 56  10.00                  5.80         8.60
# 55   9.40                  7.51         9.14
# 53   9.38                  8.46         9.03
# 54   9.38                  6.26         8.01
# 52   8.80                  7.19         8.15
# 50   8.76                  5.77         7.56
# 51   8.76                  5.82         8.48
# 49   8.75                  4.17         8.50
# 47   8.14                  6.30         8.31
# 48   8.14                  7.13         8.70
# 46   8.13                  6.34         7.60
# 45   8.12                  6.33         7.78
# 44   8.10                  7.62         8.16
# 43   7.52                  6.96         8.79
# 42   7.51                  6.53         8.23
# 40   7.50                  6.10         7.93
# 41   7.50                  6.95         9.34
# 38   7.20                  0.00         0.00
# 39   7.20                  7.86         9.72
# 37   6.90                  6.08         7.91
# ...

# %%
temporal_ips = df.groupby(['data_referencia']).agg(
    psicossociais=('ips', 'mean'),
    desempenho_academico=('ida', 'mean'),
    engajamento=('ieg', 'mean'),
).reset_index().round(2).sort_values(by='data_referencia', ascending=True)

temporal_ips
# Out:
#   data_referencia  psicossociais  desempenho_academico  engajamento
# 0      2022-01-01           6.90                  6.09         7.89
# 1      2023-01-01           5.12                  6.66         8.70
# 2      2024-01-01           6.83                  6.35         7.37

# %%
dados_usaveis=temporal_ips.set_index("data_referencia")
dados_usaveis.head()
# Out:
#                  psicossociais  desempenho_academico  engajamento
# data_referencia
# 2022-01-01                6.90                  6.09         7.89
# 2023-01-01                5.12                  6.66         8.70
# 2024-01-01                6.83                  6.35         7.37

# %%
fig, ax = plt.subplots(figsize=(20, 8))

cores = {'psicossociais': '#8338EC', 'desempenho_academico': '#457B9D', 'engajamento': '#06D6A0'}
estilos = {'psicossociais': '-', 'desempenho_academico': '-.', 'engajamento': ':'}
labels = {'psicossociais': 'IPS — Psicossocial', 'desempenho_academico': 'IDA — Desempenho Acadêmico', 'engajamento': 'IEG — Engajamento'}

for col in dados_usaveis.columns:
    ax.plot(dados_usaveis.index, dados_usaveis[col],
            label=labels[col], color=cores[col],
            linestyle=estilos[col], marker='o', linewidth=2.5, markersize=8)
    for x, y in zip(dados_usaveis.index, dados_usaveis[col]):
        ax.annotate(f'{y:.2f}', (x, y), textcoords='offset points',
                    xytext=(0, 10), ha='center', fontsize=11, color=cores[col], fontweight='bold')

ax.set_title('Evolução Temporal: IPS, IDA e IEG (2022–2024)', fontsize=16, fontweight='bold', pad=15)
ax.set_xlabel('Ano de Referência', fontsize=13)
ax.set_ylabel('Média do Indicador (0–10)', fontsize=13)
ax.legend(title='Indicadores', fontsize=12, title_fontsize=12)
ax.grid(True, linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %%
df2 = df[['ips', "ida", 'ieg']]
df2.head()
# Out:
#    ips  ida  ieg
# 0  5.6  4.0  4.1
# 1  7.5  5.8  7.4
# 2  7.5  6.5  9.6
# 3  7.5  9.5  7.6
# 4  7.5  7.9  9.2

# %%
df2_correl = df2.corr()
df2_correl

#plotando grafico correlação
fig, ax = plt.subplots(figsize=(7, 5))
sns.heatmap(df2_correl, annot=True, fmt='.2f', cmap='RdYlGn', center=0,
            linewidths=1.5, linecolor='white', ax=ax,
            annot_kws={'size': 14, 'weight': 'bold'})
ax.set_title('Correlação: IPS × IDA × IEG', fontsize=14, fontweight='bold', pad=12)
ax.set_xticklabels(['IPS','IDA','IEG'], fontsize=12)
ax.set_yticklabels(['IPS','IDA','IEG'], fontsize=12, rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Análises para pergunta 6

# %%
temporal_ipp = df.groupby(['data_referencia']).agg(
    psicossociais=('ipp', 'mean'),
    defasagem=('ian', 'mean'),
).reset_index().round(2).sort_values(by='data_referencia', ascending=True)

temporal_ipp
# Out:
#   data_referencia  psicossociais  defasagem
# 0      2022-01-01            NaN       6.42
# 1      2023-01-01           7.56       7.24
# 2      2024-01-01           7.55       7.68

# %%
temporal_ipp.describe()
# Out:
#        psicossociais  defasagem
# count       2.000000   3.000000
# mean        7.555000   7.113333
# std         0.007071   0.639479
# min         7.550000   6.420000
# 25%         7.552500   6.830000
# 50%         7.555000   7.240000
# 75%         7.557500   7.460000
# max         7.560000   7.680000

# %%
temporal_ipp = df.groupby(['data_referencia']).agg(
    psicopedagógicas=('ipp', 'mean'),
    defasagem=('ian', 'mean'),
).reset_index().round(2).sort_values(by='data_referencia', ascending=True)

temporal_ipp=temporal_ipp.set_index("data_referencia")

fig, ax = plt.subplots(figsize=(20, 8))

cores_ipp = {'psicopedagógicas': '#F4A261', 'defasagem': '#2A9D8F'}
labels_ipp = {'psicopedagógicas': 'IPP — Psicopedagógico', 'defasagem': 'IAN — Nível de Aprendizado'}
estilos_ipp = {'psicopedagógicas': '-', 'defasagem': '--'}

for col in temporal_ipp.columns:
    ax.plot(temporal_ipp.index, temporal_ipp[col],
            label=labels_ipp[col], color=cores_ipp[col],
            linestyle=estilos_ipp[col], marker='D', linewidth=2.5, markersize=9)
    for x, y in zip(temporal_ipp.index, temporal_ipp[col]):
        ax.annotate(f'{y:.2f}', (x, y), textcoords='offset points',
                    xytext=(0, 11), ha='center', fontsize=11, color=cores_ipp[col], fontweight='bold')

ax.set_title('Evolução Temporal: IPP × IAN (2022–2024)', fontsize=16, fontweight='bold', pad=15)
ax.set_xlabel('Ano de Referência', fontsize=13)
ax.set_ylabel('Média do Indicador (0–10)', fontsize=13)
ax.legend(title='Indicadores', fontsize=12, title_fontsize=12)
ax.grid(True, linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %%
temporal_ipp
# Out:
#                  psicopedagógicas  defasagem
# data_referencia
# 2022-01-01                    NaN       6.42
# 2023-01-01                   7.56       7.24
# 2024-01-01                   7.55       7.68

# %%
ips_correl = df[['ipp', "ian"]].dropna()
ips_correl.head()
# Out:
#           ipp   ian
# 860  7.916667   5.0
# 861  7.916667   5.0
# 862  8.125000  10.0
# 863  8.333333   5.0
# 864  8.333333   5.0

# %%
ips_correl = ips_correl.corr()

fig, ax = plt.subplots(figsize=(5, 4))
sns.heatmap(ips_correl, annot=True, fmt='.2f', cmap='coolwarm', center=0,
            linewidths=2, linecolor='white', ax=ax, vmin=-1, vmax=1,
            annot_kws={'size': 16, 'weight': 'bold'})
ax.set_title('Correlação: IPP × IAN\n(0.12 = muito baixa)', fontsize=13, fontweight='bold', pad=12)
ax.set_xticklabels(['IPP','IAN'], fontsize=12)
ax.set_yticklabels(['IPP','IAN'], fontsize=12, rotation=0)
plt.tight_layout()
plt.show()

# %%
contegem_ipp = df[['ipp', "ian"]]
print(f'Quantidade de dados nulos: {contegem_ipp.isnull().sum().sum()}')
# Out:
# Quantidade de dados nulos: 1038

# %% [markdown]
# # Análises para pergunta  7

# %% [markdown]
# para a pergunta 7 e 9
#
# Ponto de virada (IPV): Quais comportamentos - acadêmicos, emocionais ou de engajamento - mais influenciam o IPV ao longo do tempo?
#
# 1. Métricas Acadêmicas
# Estas métricas avaliam o desempenho técnico e a adequação escolar do aluno:
# • IDA (Indicador de Desempenho Acadêmico): É a média das notas em Português, Matemática e Inglês. Existe uma forte correlação estatística entre o IDA e o sucesso geral do aluno (90% da variação do índice geral INDE é explicada pela combinação de IDA e engajamento).
# • IAN (Indicador de Adequação de Nível): Avalia a defasagem idade-série. Alunos "em fase" tendem a apresentar melhores resultados no IPV.
# • Potencial Acadêmico (Subdimensão do IPV): Inclui a avaliação de educadores sobre o domínio da leitura, interpretação de texto, produção escrita e raciocínio lógico (Questões 7 a 9 do questionário IPV).
# • Desempenho Cognitivo (do IPP): Avaliação de pedagogos sobre a capacidade do aluno de perceber e compreender estímulos de aprendizado (Questão 1 do IPP).
# 2. Métricas Emocionais e Comportamentais
# Estas métricas avaliam o estado psicológico, a postura e a interação social:
# • IPS (Indicador Psicossocial): Avaliação feita por psicólogos sobre a dimensão emocional, comportamento, socialização e dinâmica familiar.
# • IAA (Indicador de Autoavaliação): A percepção subjetiva do próprio aluno. A métrica de motivação para estudar (Questão 2 do IAA) é um ponto chave para correlacionar com o "despertar" do ponto de virada.
# • Desenvolvimento Emocional (Subdimensão do IPV): Avalia a postura positiva, confiança, curiosidade, determinação e foco (Questões 4 e 5 do IPV).
# • IPP (Indicador Psicopedagógico): Avalia o estado emocional, comportamento e interações sociais no ambiente de aprendizado (Questões 2 a 4 do IPP).
# 3. Métricas de Engajamento
# • IEG (Indicador de Engajamento): Mede a entrega de lições de casa e a participação em atividades de voluntariado. O engajamento é um preditor fundamental para o IPV; 72% dos alunos que atingiram o Ponto de Virada realizaram todas as provas e atividades propostas.
# Pontos de Correlação Identificados nas Fontes
# Para sua análise no Datathon, considere estes padrões observados em alunos que atingem o Ponto de Virada:
# • Pedra Topázio/Ametista: 98% dos alunos que atingem o IPV pertencem a esses grupos de alto desempenho.
# • Quartil Q4 do IDA: 62% dos alunos "Ponto de Virada" estão entre os 25% com as maiores notas acadêmicas.
# • Apoio Familiar: O IPV integra em seu cálculo o grau de suporte que o aluno recebe da família (Questão 6 do IPV).
# Essas métricas permitem identificar quais comportamentos específicos (como aumento da curiosidade ou melhora nas notas de matemática) precedem o momento em que o aluno é classificado como tendo atingido o "Ponto de Virada".

# %%
#academicos
df07a = df[['data_referencia','ipv','ida', "ian", 'ipp']]
df07a.head()
# Out:
#   data_referencia    ipv  ida   ian  ipp
# 0      2022-01-01  7.278  4.0   5.0  NaN
# 1      2022-01-01  7.875  5.8  10.0  NaN
# 2      2022-01-01  8.500  6.5  10.0  NaN
# 3      2022-01-01  7.556  9.5   5.0  NaN
# 4      2022-01-01  7.167  7.9   5.0  NaN

# %%
df07a.count()
# Out:
# data_referencia    3030
# ipv                2852
# ida                2852
# ian                3030
# ipp                1992
# dtype: int64

# %%
df07a.isna().sum()
# Out:
# data_referencia       0
# ipv                 178
# ida                 178
# ian                   0
# ipp                1038
# dtype: int64

# %%
# se for necessário df07.dropna(inplace=True)

# %%
df07a_plot = df07a.groupby(['data_referencia']).agg(
    ipv=('ipv', 'mean'),
    ida=('ida', 'mean'),
    ian=('ian', 'mean'),
    ipp=('ipp', 'mean'),
).reset_index().round(2).sort_values(by='data_referencia', ascending=True)

df07a_plot
# Out:
#   data_referencia   ipv   ida   ian   ipp
# 0      2022-01-01  7.25  6.09  6.42   NaN
# 1      2023-01-01  8.03  6.66  7.24  7.56
# 2      2024-01-01  7.35  6.35  7.68  7.55

# %%
df07a_plot = df07a_plot.set_index(["data_referencia"])

# %%
plt.figure(figsize=(12, 6))

nomes = {'ipv': 'IPV — Ponto de Virada', 'ida': 'IDA — Desempenho Acadêmico',
         'ian': 'IAN — Nível de Aprendizado', 'ipp': 'IPP — Psicopedagógico'}

for coluna in df07a_plot.columns:
    if coluna == 'ipv':
        plt.plot(df07a_plot.index, df07a_plot[coluna], label=nomes[coluna],
                 linestyle='--', marker='o', linewidth=2.5)
    else:
        plt.plot(df07a_plot.index, df07a_plot[coluna], label=nomes[coluna],
                 linestyle='-', marker='s')
    for x, y in zip(df07a_plot.index, df07a_plot[coluna]):
        plt.annotate(f'{y:.2f}', (x, y), textcoords='offset points',
                     xytext=(0, 9), ha='center', fontsize=9)

plt.title('Evolução dos Indicadores: Destaque para o IPV (Tracejado)\nIndicadores Acadêmicos', fontweight='bold')
plt.xlabel('Data de Referência')
plt.ylabel('Valores')
plt.legend(title='Indicadores')
plt.grid(True, linestyle=':', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
#2. Métricas Emocionais e Comportamentais
df07e = df[['data_referencia','ipv','ips','iaa','ipp']]
df07e.head()
# Out:
#   data_referencia    ipv  ips  iaa  ipp
# 0      2022-01-01  7.278  5.6  8.3  NaN
# 1      2022-01-01  7.875  7.5  9.2  NaN
# 2      2022-01-01  8.500  7.5  9.0  NaN
# 3      2022-01-01  7.556  7.5  9.5  NaN
# 4      2022-01-01  7.167  7.5  9.0  NaN

# %%
df07e_plot = df07e.groupby(['data_referencia']).agg(
    ipv=('ipv', 'mean'),
    ips=('ips', 'mean'),
    iaa=('iaa', 'mean'),
    ipp=('ipp', 'mean'),
   ).reset_index().round(2).sort_values(by='data_referencia', ascending=True)

df07e_plot = df07e_plot.set_index(["data_referencia"]) # colocar como index

df07e_plot
# Out:
#                   ipv   ips   iaa   ipp
# data_referencia
# 2022-01-01       7.25  6.90  8.27   NaN
# 2023-01-01       8.03  5.12  6.90  7.56
# 2024-01-01       7.35  6.83  8.54  7.55

# %%
plt.figure(figsize=(12, 6))

nomes_e = {'ipv': 'IPV — Ponto de Virada', 'ips': 'IPS — Psicossocial',
           'iaa': 'IAA — Autoavaliação', 'ipp': 'IPP — Psicopedagógico'}

for coluna in df07e_plot.columns:
    if coluna == 'ipv':
        plt.plot(df07e_plot.index, df07e_plot[coluna], label=nomes_e[coluna],
                 linestyle='--', marker='o', linewidth=2.5)
    else:
        plt.plot(df07e_plot.index, df07e_plot[coluna], label=nomes_e[coluna],
                 linestyle='-', marker='s')
    for x, y in zip(df07e_plot.index, df07e_plot[coluna]):
        plt.annotate(f'{y:.2f}', (x, y), textcoords='offset points',
                     xytext=(0, 9), ha='center', fontsize=9)

plt.title('Evolução dos Indicadores: Destaque para o IPV (Tracejado)\nIndicadores Emocionais e Comportamentais', fontweight='bold')
plt.xlabel('Data de Referência')
plt.ylabel('Valores')
plt.legend(title='Indicadores')
plt.grid(True, linestyle=':', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
#3. Métricas de Engajamento
df07en = df[['data_referencia','ipv','ieg']]
df07en.head()
# Out:
#   data_referencia    ipv  ieg
# 0      2022-01-01  7.278  4.1
# 1      2022-01-01  7.875  7.4
# 2      2022-01-01  8.500  9.6
# 3      2022-01-01  7.556  7.6
# 4      2022-01-01  7.167  9.2

# %%
df07en = df07en.groupby(['data_referencia']).agg(
    ipv=('ipv', 'mean'),
    ieg=('ieg', 'mean'),
   ).reset_index().round(2).sort_values(by='data_referencia', ascending=True)

df07en = df07en.set_index(["data_referencia"]) # colocar como index

df07en
# Out:
#                   ipv   ieg
# data_referencia
# 2022-01-01       7.25  7.89
# 2023-01-01       8.03  8.70
# 2024-01-01       7.35  7.37

# %%
fig = plt.figure(figsize=(20, 12))

nomes_en  = {'ipv': 'IPV — Ponto de Virada', 'ieg': 'IEG — Engajamento'}
nomes_e2  = {'ipv': 'IPV — Ponto de Virada', 'ips': 'IPS — Psicossocial',
             'iaa': 'IAA — Autoavaliação',   'ipp': 'IPP — Psicopedagógico'}
nomes_a2  = {'ipv': 'IPV — Ponto de Virada', 'ida': 'IDA — Desempenho Acadêmico',
             'ian': 'IAN — Nível de Aprendizado', 'ipp': 'IPP — Psicopedagógico'}

def plot_ax(ax, data, nomes, title):
    for col in data.columns:
        ls = '--' if col == 'ipv' else '-'
        mk = 'o' if col == 'ipv' else 's'
        lw = 2.5 if col == 'ipv' else 1.8
        ax.plot(data.index, data[col], label=nomes.get(col, col),
                linestyle=ls, marker=mk, linewidth=lw)
        for x, y in zip(data.index, data[col]):
            ax.annotate(f'{y:.2f}', (x, y), textcoords='offset points',
                        xytext=(0, 8), ha='center', fontsize=8)
    ax.set_title(title, fontsize=13, fontweight='bold')
    ax.legend(fontsize=9)
    ax.grid(True, linestyle=':', alpha=0.5)
    ax.set_xlabel('Ano')
    ax.set_ylabel('Média')

ax1 = fig.add_subplot(2, 2, 1)
plot_ax(ax1, df07en, nomes_en, 'Indicadores de Engajamento')

ax2 = fig.add_subplot(2, 2, 2)
plot_ax(ax2, df07e_plot, nomes_e2, 'Indicadores Emocionais e Comportamentais')

ax3 = fig.add_subplot(2, 2, 3)
plot_ax(ax3, df07a_plot, nomes_a2, 'Indicadores Acadêmicos')

plt.tight_layout()
plt.show()

# %% [markdown]
# Metricas consideradas Emocionais e de engajamento podem tendem a ter maior influencia ao IPV (indicador de ponto de virada), dado que enquanto os indicadores IPS e IAA (emocionais) caem ao longo do tempo, o IPV tende tambem a cair no ano seguinte, já o indicador IEG (Engajamento) tende a ter o mesmo comportamento que o IPV, ou seja, se ele subir, o indicador de IPV também sobe, do contrário o mesmo. Já o unico indicador Acadêmico que possui uma certa relação com o IPV é o IDA, dado que se ele sobre o IPV tambem sobe e de tiver queda há tendencia de ter queda tambem

# %% [markdown]
# # Análises para pergunta  10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3030 entries, 0 to 3029
# Data columns (total 64 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   data_referencia        3030 non-null   object
#  1   ra                     3030 non-null   object
#  2   fase                   3030 non-null   object
#  3   turma                  3030 non-null   object
#  4   nome                   860 non-null    object
#  5   ano_nasc               860 non-null    float64
#  6   idade_22               860 non-null    float64
#  7   gênero                 3030 non-null   object
#  8   ano_ingresso           3030 non-null   int64
#  9   instituição_de_ensino  3029 non-null   object
#  10  pedra_20               754 non-null    object
#  11  pedra_21               1061 non-null   object
#  12  pedra_22               1932 non-null   object
#  13  inde_22                1932 non-null   float64
# ...

# %%
df10 = df.query('ra == "RA-1000"')
df10 = df10[['data_referencia','ra','pedra_20','pedra_21','pedra_22','pedra_2023','pedra_2024']]
df10.head()
# Out:
#      data_referencia       ra pedra_20 pedra_21 pedra_22 pedra_2023 pedra_2024
# 1529      2023-01-01  RA-1000      NaN      NaN      NaN   Ametista        NaN
# 2644      2024-01-01  RA-1000      NaN      NaN      NaN        NaN    Topázio

# %%
df10.query('ra == "RA-1000"')
# Out:
#      data_referencia       ra pedra_20 pedra_21 pedra_22 pedra_2023 pedra_2024
# 1529      2023-01-01  RA-1000      NaN      NaN      NaN   Ametista        NaN
# 2644      2024-01-01  RA-1000      NaN      NaN      NaN        NaN    Topázio

# %%
# 1. Mapeamento numérico das pedras conforme dicionário de dados [4, 6]
mapa_pedras = {
    'Quartzo': 1,
    'Ágata': 2,
    'Ametista': 3,
    'Topázio': 4
}

# %%
df_consolidado = df.groupby('ra')[['pedra_20', 'pedra_21', 'pedra_22', 'pedra_2023', 'pedra_2024']].first().reset_index()

# %%
print(df_consolidado.query('ra == "RA-1000"'))
# Out:
#         ra pedra_20 pedra_21 pedra_22 pedra_2023 pedra_2024
# 3  RA-1000     None     None     None   Ametista    Topázio

# %%
# 2. Conversão para valores numéricos para cálculo de evolução
cols_pedras = ['pedra_20', 'pedra_21', 'pedra_22', 'pedra_2023', 'pedra_2024']
for col in cols_pedras:
    df_consolidado[f'v_{col}'] = df_consolidado[col].map(mapa_pedras)

# %%
df_consolidado.head()
# Out:
#         ra  pedra_20  pedra_21  pedra_22 pedra_2023 pedra_2024  v_pedra_20  \
# 0     RA-1  Ametista  Ametista   Quartzo       None       None         3.0
# 1    RA-10      None     Ágata   Quartzo       None       None         NaN
# 2   RA-100  Ametista   Topázio  Ametista       None       None         3.0
# 3  RA-1000      None      None      None   Ametista    Topázio         NaN
# 4  RA-1001      None      None      None    Topázio   Ametista         NaN
#
#    v_pedra_21  v_pedra_22  v_pedra_2023  v_pedra_2024
# 0         3.0         1.0           NaN           NaN
# 1         2.0         1.0           NaN           NaN
# 2         4.0         3.0           NaN           NaN
# 3         NaN         NaN           3.0           4.0
# 4         NaN         NaN           4.0           3.0

# %%
# 3. Cálculo da Evolução Recente (Exemplo: 2023 para 2024)
# O impacto real é medido pela variação positiva [8, 9]
df_consolidado['evolucao_23_24'] = df_consolidado['v_pedra_2024'] - df_consolidado['v_pedra_2023']

def classificar_jornada(valor):
    if valor > 0: return 'Avanço'
    elif valor == 0: return 'Neutra'
    elif valor < 0: return 'Recuo'
    else: return 'Sem Dados'

df_consolidado['jornada'] = df_consolidado['evolucao_23_24'].apply(classificar_jornada)
df_consolidado
# Out:
#            ra  pedra_20  pedra_21  pedra_22 pedra_2023 pedra_2024  v_pedra_20  \
# 0        RA-1  Ametista  Ametista   Quartzo       None       None         3.0
# 1       RA-10      None     Ágata   Quartzo       None       None         NaN
# 2      RA-100  Ametista   Topázio  Ametista       None       None         3.0
# 3     RA-1000      None      None      None   Ametista    Topázio         NaN
# 4     RA-1001      None      None      None    Topázio   Ametista         NaN
# ...       ...       ...       ...       ...        ...        ...         ...
# 1656   RA-995      None      None      None      Agata    Quartzo         NaN
# 1657   RA-996      None      None      None    Topázio       None         NaN
# 1658   RA-997      None      None      None   Ametista       None         NaN
# 1659   RA-998      None      None      None   Ametista       None         NaN
# 1660   RA-999      None      None      None    Topázio       None         NaN
#
# ...

# %%
df_limpo_10 =df_consolidado.dropna()
df_limpo_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 105 entries, 35 to 1595
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ra              105 non-null    object
#  1   pedra_20        105 non-null    object
#  2   pedra_21        105 non-null    object
#  3   pedra_22        105 non-null    object
#  4   pedra_2023      105 non-null    object
#  5   pedra_2024      105 non-null    object
#  6   v_pedra_20      105 non-null    float64
#  7   v_pedra_21      105 non-null    float64
#  8   v_pedra_22      105 non-null    float64
#  9   v_pedra_2023    105 non-null    float64
#  10  v_pedra_2024    105 non-null    float64
#  11  evolucao_23_24  105 non-null    float64
#  12  jornada         105 non-null    object
# dtypes: float64(6), object(7)
# memory usage: 11.5+ KB

# %%
# 4. Resumo estatístico para responder à pergunta de 2023 para 2024
impacto_total = df_limpo_10['jornada'].value_counts(normalize=True) * 100
print("Distribuição da Jornada dos Alunos (%):")
print(impacto_total)
# Out:
# Distribuição da Jornada dos Alunos (%):
# jornada
# Neutra    60.00000
# Avanço    30.47619
# Recuo      9.52381
# Name: proportion, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(8, 7))
counts = df_limpo_10['jornada'].value_counts()
cores_pizza = ['#2A9D8F', '#E9C46A', '#E63946'][:len(counts)]
counts.plot.pie(autopct='%1.1f%%', ax=ax, colors=cores_pizza,
                wedgeprops=dict(edgecolor='white', linewidth=2),
                textprops={'fontsize': 13, 'fontweight': 'bold'})
ax.set_ylabel('')
ax.set_title('Jornada dos Alunos: 2023 → 2024', fontsize=14, fontweight='bold', pad=15)
plt.tight_layout()
plt.show()

# %%
# 4. Resumo estatístico para responder à pergunta de 2023 para 2024
df_limpo_10['jornada'].value_counts()
# Out:
# jornada
# Neutra    63
# Avanço    32
# Recuo     10
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(8, 7))
counts2 = df_limpo_10['pedra_2024'].value_counts()
cores_pedras = ['#457B9D', '#8338EC', '#F4A261', '#2A9D8F'][:len(counts2)]
counts2.plot.pie(autopct='%1.1f%%', ax=ax, colors=cores_pedras,
                 wedgeprops=dict(edgecolor='white', linewidth=2),
                 textprops={'fontsize': 13, 'fontweight': 'bold'})
ax.set_ylabel('')
ax.set_title('Distribuição por Categoria de Pedra — 2024', fontsize=14, fontweight='bold', pad=15)
plt.tight_layout()
plt.show()

# %%
# 4. Resumo estatístico para responder à pergunta de 2023 para 2024
proporção23_24 = df_limpo_10['pedra_2024'].value_counts(normalize=True) * 100
print(proporção23_24)
# Out:
# pedra_2024
# Topázio     54.285714
# Ametista    32.380952
# Quartzo     13.333333
# Name: proportion, dtype: float64

# %%
# Libs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from pathlib import Path

# %% [markdown]
# ## Defini caminho do arquivo

# %%
arquivo_excel = (
    Path.cwd()
    .parents[1] / 'data' / 'raw' / 'BASE_DE_DADOS_PEDE_2024_DATATHON.xlsx'
)

assert arquivo_excel.exists(), "❌ Arquivo Excel não encontrado"
print("✅ Arquivo encontrado:", arquivo_excel.name)
# Out:
# ✅ Arquivo encontrado: BASE_DE_DADOS_PEDE_2024_DATATHON.xlsx

# %% [markdown]
# ## Carrega as planilhas e adiciona coluna de ano de referência

# %%
excel_file = pd.ExcelFile(arquivo_excel)

df1 = pd.read_excel(arquivo_excel, sheet_name='PEDE2022')
df2 = pd.read_excel(arquivo_excel, sheet_name='PEDE2023')
df3 = pd.read_excel(arquivo_excel, sheet_name='PEDE2024')

print("📊 Shapes:")
print("PEDE2022:", df1.shape)
print("PEDE2023:", df2.shape)
print("PEDE2024:", df3.shape)

df1['ano_referencia'] = 2022
df2['ano_referencia'] = 2023
df3['ano_referencia'] = 2024
# Out:
# 📊 Shapes:
# PEDE2022: (860, 42)
# PEDE2023: (1014, 48)
# PEDE2024: (1156, 50)

# %% [markdown]
# ## Empilhamento vertical

# %%
df_final = pd.concat(
    [df1, df2, df3],
    axis=0,
    ignore_index=True,
    sort=False
)

print("✅ Dataset empilhado com sucesso")
print("Shape final:", df_final.shape)
# Out:
# ✅ Dataset empilhado com sucesso
# Shape final: (3030, 63)

# %% [markdown]
# ## Cria coluna de data

# %%
df_final.insert(
    0,
    'data_referencia',
    pd.to_datetime(df_final['ano_referencia'], format='%Y', errors='coerce')
)

# %% [markdown]
# ## Ordena cronologicamente

# %%
df_final = (
    df_final
    .sort_values('data_referencia')
    .reset_index(drop=True)
)

# %% [markdown]
# ## Validação

# %%
print("\n🔎 Verificação temporal:")
print(df_final[['ano_referencia', 'data_referencia']].drop_duplicates().sort_values('ano_referencia'))

print("\n📈 Registros por ano:")
print(df_final['ano_referencia'].value_counts().sort_index())
# Out:
# 🔎 Verificação temporal:
#       ano_referencia data_referencia
# 0               2022      2022-01-01
# 860             2023      2023-01-01
# 1874            2024      2024-01-01
#
# 📈 Registros por ano:
# ano_referencia
# 2022     860
# 2023    1014
# 2024    1156
# Name: count, dtype: int64

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

df_final
# Out:
#      data_referencia       RA Fase Turma       Nome  Ano nasc  Idade 22  \
# 0         2022-01-01     RA-1    7     A    Aluno-1    2003.0      19.0
# 1         2022-01-01    RA-61    5     B   Aluno-61    2007.0      15.0
# 2         2022-01-01   RA-610    1     L  Aluno-610    2013.0       9.0
# 3         2022-01-01   RA-611    1     M  Aluno-611    2010.0      12.0
# 4         2022-01-01   RA-612    1     M  Aluno-612    2012.0      10.0
# ...              ...      ...  ...   ...        ...       ...       ...
# 3025      2024-01-01  RA-1438   1M    1M        NaN       NaN       NaN
# 3026      2024-01-01  RA-1437   1M    1M        NaN       NaN       NaN
# 3027      2024-01-01  RA-1436   1M    1M        NaN       NaN       NaN
# 3028      2024-01-01  RA-1486   2L    2L        NaN       NaN       NaN
# 3029      2024-01-01   RA-995   1E    1E        NaN       NaN       NaN
#
#          Gênero  Ano ingresso Instituição de ensino  Pedra 20  Pedra 21  \
# 0        Menina          2016        Escola Pública  Ametista  Ametista
# 1        Menino          2021        Escola Pública       NaN     Ágata
# 2        Menina          2022        Escola Pública       NaN       NaN
# 3        Menino          2021        Escola Pública       NaN  Ametista
# 4        Menina          2021        Escola Pública       NaN   Topázio
# ...         ...           ...                   ...       ...       ...
# 3025   Feminino          2024               Pública       NaN       NaN
# 3026   Feminino          2024               Pública       NaN       NaN
# 3027   Feminino          2024               Pública       NaN       NaN
# 3028  Masculino          2024               Pública       NaN       NaN
# 3029   Feminino          2023               Pública       NaN       NaN
#
#       Pedra 22  INDE 22     Cg    Cf    Ct  Nº Av    Avaliador1  \
# 0      Quartzo    5.783  753.0  18.0  10.0    4.0   Avaliador-5
# 1     Ametista    7.533  298.0  20.0   8.0    3.0   Avaliador-5
# 2      Topázio    8.180   91.0  21.0   3.0    3.0   Avaliador-4
# 3     Ametista    7.756  214.0  54.0   4.0    3.0   Avaliador-7
# 4     Ametista    7.594  273.0  71.0   6.0    3.0   Avaliador-7
# ...        ...      ...    ...   ...   ...    ...           ...
# 3025       NaN      NaN    NaN   NaN   NaN    2.0  Avaliador-17
# 3026       NaN      NaN    NaN   NaN   NaN    2.0  Avaliador-17
# 3027       NaN      NaN    NaN   NaN   NaN    2.0  Avaliador-17
# 3028       NaN      NaN    NaN   NaN   NaN    3.0  Avaliador-19
# 3029       NaN      NaN    NaN   NaN   NaN    2.0  Avaliador-15
#
#                         Rec Av1    Avaliador2                    Rec Av2  \
# 0         Mantido na Fase atual  Avaliador-27  Promovido de Fase + Bolsa
# 1         Mantido na Fase atual  Avaliador-27      Mantido na Fase atual
# 2         Mantido na Fase atual   Avaliador-2          Promovido de Fase
# 3     Promovido de Fase + Bolsa   Avaliador-3          Promovido de Fase
# 4             Promovido de Fase   Avaliador-3      Mantido na Fase atual
# ...                         ...           ...                        ...
# 3025                        NaN   Avaliador-2                        NaN
# 3026                        NaN   Avaliador-2                        NaN
# 3027                        NaN   Avaliador-2                        NaN
# 3028                        NaN  Avaliador-25                        NaN
# 3029                        NaN   Avaliador-2                        NaN
#
#         Avaliador3                    Rec Av3    Avaliador4  \
# 0     Avaliador-28          Promovido de Fase  Avaliador-31
# 1     Avaliador-24  Promovido de Fase + Bolsa  Avaliador-31
# 2              NaN      Mantido na Fase atual           NaN
# 3              NaN          Promovido de Fase           NaN
# 4              NaN      Mantido na Fase atual           NaN
# ...            ...                        ...           ...
# 3025           NaN                        NaN           NaN
# 3026           NaN                        NaN           NaN
# 3027           NaN                        NaN           NaN
# 3028   Avaliador-2                        NaN           NaN
# 3029           NaN                        NaN           NaN
#
#                     Rec Av4     IAA       IEG    IPS    Rec Psicologia   IDA  \
# 0     Mantido na Fase atual   8.300  4.100000  5.600  Requer avaliação  4.00
# 1                       NaN   9.200  7.400000  7.500      Não atendido  5.80
# 2                       NaN   9.000  9.600000  7.500    Sem limitações  6.50
# 3                       NaN   9.500  7.600000  7.500      Não atendido  9.50
# 4                       NaN   9.000  9.200000  7.500      Não atendido  7.90
# ...                     ...     ...       ...    ...               ...   ...
# 3025                    NaN  10.002  9.000000  7.510               NaN  7.00
# 3026                    NaN   8.502  9.347826  7.510               NaN  8.00
# 3027                    NaN   7.418  8.674948  7.510               NaN  8.00
# 3028                    NaN   8.002  5.431373  6.260               NaN  5.75
# 3029                    NaN  10.002  5.389610  5.635               NaN  2.00
#
#       Matem  Portug  Inglês Indicado Atingiu PV       IPV   IAN  \
# 0       2.7     3.5     6.0      Sim        Não  7.278000   5.0
# 1       1.7     6.3     9.3      Sim        Não  7.875000  10.0
# 2       6.0     7.0     NaN      Não        Sim  8.500000  10.0
# 3      10.0     9.0     NaN      Sim        Não  7.556000   5.0
# 4       9.7     6.2     NaN      Não        Não  7.167000   5.0
# ...     ...     ...     ...      ...        ...       ...   ...
# 3025    NaN     NaN     NaN      NaN        NaN  9.175000   5.0
# 3026    NaN     NaN     NaN      NaN        NaN  7.920000   5.0
# 3027    NaN     NaN     NaN      NaN        NaN  7.170000   5.0
# 3028    NaN     NaN     NaN      NaN        NaN  7.056667  10.0
# 3029    NaN     NaN     NaN      NaN        NaN  4.250000   5.0
#
#                    Fase ideal  Defasagem  \
# 0     Fase 8 (Universitários)         -1
# 1              Fase 5 (1º EM)          0
# 2             Fase 1 (4º ano)          0
# 3        Fase 3 (7º e 8º ano)         -2
# 4        Fase 2 (5º e 6º ano)         -1
# ...                       ...        ...
# 3025                      NaN         -1
# 3026                      NaN         -1
# 3027                      NaN         -1
# 3028                      NaN          0
# 3029                      NaN         -2
#
#                                              Destaque IEG  \
# 0     Melhorar: Melhorar a sua entrega de lições de casa.
# 1     Melhorar: Melhorar a sua entrega de lições de casa.
# 2         Destaque: A sua boa entrega das lições de casa.
# 3         Destaque: A sua boa entrega das lições de casa.
# 4         Destaque: A sua boa entrega das lições de casa.
# ...                                                   ...
# 3025                                                  NaN
# 3026                                                  NaN
# 3027                                                  NaN
# 3028                                                  NaN
# 3029                                                  NaN
#
#                                             Destaque IDA  \
# 0     Melhorar: Empenhar-se mais nas aulas e avaliações.
# 1     Melhorar: Empenhar-se mais nas aulas e avaliações.
# 2     Melhorar: Empenhar-se mais nas aulas e avaliações.
# 3        Destaque: As suas boas notas na Passos Mágicos.
# 4        Destaque: As suas boas notas na Passos Mágicos.
# ...                                                  ...
# 3025                                                 NaN
# 3026                                                 NaN
# 3027                                                 NaN
# 3028                                                 NaN
# 3029                                                 NaN
#
#                                                        Destaque IPV  \
# 0         Melhorar: Integrar-se mais aos Princípios Passos Mágicos.
# 1     Destaque: A sua boa integração aos Princípios Passos Mágicos.
# 2     Destaque: A sua boa integração aos Princípios Passos Mágicos.
# 3     Destaque: A sua boa integração aos Princípios Passos Mágicos.
# 4         Melhorar: Integrar-se mais aos Princípios Passos Mágicos.
# ...                                                             ...
# 3025                                                            NaN
# 3026                                                            NaN
# 3027                                                            NaN
# 3028                                                            NaN
# 3029                                                            NaN
#
#       ano_referencia  INDE 2023 Pedra 2023 Nome Anonimizado  \
# 0               2022        NaN        NaN              NaN
# 1               2022        NaN        NaN              NaN
# 2               2022        NaN        NaN              NaN
# 3               2022        NaN        NaN              NaN
# 4               2022        NaN        NaN              NaN
# ...              ...        ...        ...              ...
# 3025            2024        NaN        NaN       Aluno-1438
# 3026            2024        NaN        NaN       Aluno-1437
# 3027            2024        NaN        NaN       Aluno-1436
# 3028            2024        NaN        NaN       Aluno-1486
# 3029            2024        NaN        NaN        Aluno-995
#
#              Data de Nasc Idade Pedra 23  INDE 23       IPP  Mat  Por  Ing  \
# 0                     NaN   NaN      NaN      NaN       NaN  NaN  NaN  NaN
# 1                     NaN   NaN      NaN      NaN       NaN  NaN  NaN  NaN
# 2                     NaN   NaN      NaN      NaN       NaN  NaN  NaN  NaN
# 3                     NaN   NaN      NaN      NaN       NaN  NaN  NaN  NaN
# 4                     NaN   NaN      NaN      NaN       NaN  NaN  NaN  NaN
# ...                   ...   ...      ...      ...       ...  ...  ...  ...
# 3025  2013-11-08 00:00:00    10      NaN      NaN  8.906250  6.0  8.0  NaN
# 3026  2013-06-29 00:00:00    11      NaN      NaN  8.281250  8.0  8.0  NaN
# 3027  2013-06-24 00:00:00    11      NaN      NaN  8.281250  8.0  8.0  NaN
# 3028  2013-06-26 00:00:00    11      NaN      NaN  7.916667  6.0  5.5  NaN
# 3029  2012-04-02 00:00:00    12    Agata   6.4782  7.187500  0.0  4.0  NaN
#
#                 Fase Ideal  Destaque IPV.1 INDE 2024 Pedra 2024 Avaliador5  \
# 0                      NaN             NaN       NaN        NaN        NaN
# 1                      NaN             NaN       NaN        NaN        NaN
# 2                      NaN             NaN       NaN        NaN        NaN
# 3                      NaN             NaN       NaN        NaN        NaN
# 4                      NaN             NaN       NaN        NaN        NaN
# ...                    ...             ...       ...        ...        ...
# 3025  Fase 2 (5° e 6° ano)             NaN  8.176825    Topázio        NaN
# 3026  Fase 2 (5° e 6° ano)             NaN   7.98289   Ametista        NaN
# 3027  Fase 2 (5° e 6° ano)             NaN  7.589915   Ametista        NaN
# 3028  Fase 2 (5° e 6° ano)             NaN  6.865475      Agata        NaN
# 3029  Fase 3 (7° e 8° ano)             NaN  5.110372    Quartzo        NaN
#
#      Avaliador6                                     Escola Ativo/ Inativo  \
# 0           NaN                                        NaN            NaN
# 1           NaN                                        NaN            NaN
# 2           NaN                                        NaN            NaN
# 3           NaN                                        NaN            NaN
# 4           NaN                                        NaN            NaN
# ...         ...                                        ...            ...
# 3025        NaN                     EM Bairro Lagoa Grande       Cursando
# 3026        NaN  EM Cecilia Cristina de Oliveira Rodrigues       Cursando
# 3027        NaN                          EM Alfredo Schunk       Cursando
# 3028        NaN                EE Maria André Schunck Dona       Cursando
# 3029        NaN               EE Mario Francisco de Amorim       Cursando
#
#      Ativo/ Inativo.1
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 3025         Cursando
# 3026         Cursando
# 3027         Cursando
# 3028         Cursando
# 3029         Cursando
#
# [3030 rows x 64 columns]
